# %%
import torch

x = torch.ones(5)
y = torch.zeros(3)
w = torch.randn(5, 3, requires_grad=True)
b = torch.randn(3, requires_grad=True)
z = torch.matmul(x, w) + b
loss = torch.nn.functional.binary_cross_entropy_with_logits(z, y)

# %%
print(f'Gradient function for z = {z.grad_fn}')
print(f'Gradient function for loss = {loss.grad_fn}')
# Out:
# Gradient function for z = <AddBackward0 object at 0x7f13e5a8e0b0>
# Gradient function for loss = <BinaryCrossEntropyWithLogitsBackward0 object at 0x7f12d5053610>

# %%
loss.backward() # Compute gradients with chain rule
print(w.grad)
print(b.grad)
# Out:
# tensor([[0.3133, 0.2138, 0.1855],
#         [0.3133, 0.2138, 0.1855],
#         [0.3133, 0.2138, 0.1855],
#         [0.3133, 0.2138, 0.1855],
#         [0.3133, 0.2138, 0.1855]])
# tensor([0.3133, 0.2138, 0.1855])

# %%
z = torch.matmul(x, w) + b
print(z.requires_grad)  # Should be True

with torch.no_grad():
    z = torch.matmul(x, w) + b
print(z.requires_grad)  # Should be False
# Out:
# True
# False

# %%
z = torch.matmul(x, w) + b
print(z.requires_grad)  # Should be True
z_det = z.detach()
print(z_det.requires_grad)  # Should be False
# Out:
# True
# False
